# %% [markdown]
# <a href="https://colab.research.google.com/github/Matsumo-chi/Getting-Started-with-Python/blob/main/OpenCV%E5%85%A5%E9%96%80.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 事前準備

# %% [markdown]
# ## 必要サポートパッチのインポート
# - cv2.imshow()はGoogleColaboratoryでは使えません💦
# - ありがたいことにColab側がサポートパッチを提供してくれているのでこれを使います。
# - これはColabのパッチを使ってるので**Jupyter Notebookではうまく動きません！**

# %%
from google.colab.patches import cv2_imshow

# %% [markdown]
# ## ドライブのマウント
#
# 1. 左上のフォルダマークから「ドライブをマウント」をクリックする
#
# - <img src="https://github.com/Matsumo-chi/Getting-Started-with-Python/blob/main/imgs/%E3%83%9E%E3%82%A6%E3%83%B3%E3%83%88%E6%96%B9%E6%B3%951.png?raw=1" height=300>
#
# 2. ドライブのマウントボタンを押す
# - <img src="https://github.com/Matsumo-chi/Getting-Started-with-Python/blob/main/imgs/%E3%83%9E%E3%82%A6%E3%83%B3%E3%83%88%E6%96%B9%E6%B3%952.png?raw=1" height=300>
#
# 3. アクセスを許可するか聞かれるので、「Googleドライブに接続」をクリックして認証に進む
# - <img src="https://github.com/Matsumo-chi/Getting-Started-with-Python/blob/main/imgs/%E3%83%9E%E3%82%A6%E3%83%B3%E3%83%88%E6%96%B9%E6%B3%953.png?raw=1" height=300>
#
# 4. 認証後、マウントボタンに斜線が入り、driveフォルダ配下に「My Drive」がマウントされている
#
# - <img src="https://github.com/Matsumo-chi/Getting-Started-with-Python/blob/main/imgs/%E3%83%9E%E3%82%A6%E3%83%B3%E3%83%88%E6%96%B9%E6%B3%954.png?raw=1" height=300>

# %% [markdown]
# もしくは以下のコードを実行すること

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### 自分で画像をアップロードしたい場合
#  - 以下のコードを実行して、**ファイルを選択**から任意の画像をアップロードしてください。

# %%
from google.colab import files # colaboratoryのライブラリからファイル操作を使用する。
uploaded = files.upload() # ファイルをアップロードする。
# Out:
#      <input type="file" id="files-8a8fdc7a-ea97-48ea-81c2-2b10285ffa9a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8a8fdc7a-ea97-48ea-81c2-2b10285ffa9a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-d90ef4554fcf> in <module>()
#       1 from google.colab import files # colaboratoryのライブラリからファイル操作を使用する。
# ----> 2 uploaded = files.upload() # ファイルをアップロードする。
#
# /usr/local/lib/python3.7/dist-packages/google/colab/files.py in upload()
#      62   result = _output.eval_js(
#      63       'google.colab._files._uploadFiles("{input_id}", "{output_id}")'.format(
# ...

# %% [markdown]
# # ライブラリのインポート

# %%
import cv2

# %% [markdown]
# # 画像の表示
# `cv2.imshow()`

# %%
# 画像の読み込み
img = cv2.imread("shell.png")

# 画像の表示
cv2_imshow(img)

# %%
imgs = []

img0 = cv2_imread('')
imgs.append(img0)
img1 = cv2_imread('')
imgs.append(img1)
img2 = cv2_imread('')
imgs.append(img2)

cv2_imshow('win0',img[0])
cv2_imshow('win0',img[1])
cv2_imshow('win0',img[2])

# %%
imgs = []

imgs.append(cv2_imread(''))
imgs.append(cv2_imread(''))
imgs.append(cv2_imread(''))

for i in range(0,3):
  cv2_imshow('win'+str(i),img[i])
